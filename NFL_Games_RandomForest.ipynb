# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv("NFL Games.csv")

df.head()
# Out:
#        date  season  neutral playoff  ...  qbelo1_post  qbelo2_post  score1  score2
# 0  17-09-06    2006        0     NaN  ...  1504.240776  1541.801130      24      30
# 1  02-10-06    2006        0     NaN  ...  1539.983485  1397.514162      31       9
# 2  08-10-06    2006        0     NaN  ...  1561.811023  1548.359901      38      24
# 3  29-10-06    2006        0     NaN  ...  1504.969807  1556.282940       6      13
# 4  12-11-06    2006        0     NaN  ...  1527.741403  1478.831343      27       3
#
# [5 rows x 30 columns]

# %%
print(df.shape)
print(df.info())
print(df.isnull().sum())
# Out:
# (187, 30)
# <class 'pandas.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 30 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            187 non-null    str
#  1   season          187 non-null    int64
#  2   neutral         187 non-null    int64
#  3   playoff         11 non-null     str
#  4   team1           187 non-null    str
#  5   team2           187 non-null    str
#  6   elo1_pre        187 non-null    float64
#  7   elo2_pre        187 non-null    float64
#  8   elo_prob1       187 non-null    float64
#  9   elo_prob2       187 non-null    float64
#  10  elo1_post       187 non-null    float64
#  11  elo2_post       187 non-null    float64
#  12  qbelo1_pre      187 non-null    float64
#  13  qbelo2_pre      187 non-null    float64
#  14  qb1             187 non-null    str
#  15  qb2             187 non-null    str
#  16  qb1_value_pre   187 non-null    float64
#  17  qb2_value_pre   187 non-null    float64
#  18  qb1_adj         187 non-null    float64
#  19  qb2_adj         187 non-null    float64
#  20  qbelo_prob1     187 non-null    float64
#  21  qbelo_prob2     187 non-null    float64
#  22  qb1_game_value  187 non-null    float64
#  23  qb2_game_value  187 non-null    float64
#  24  qb1_value_post  187 non-null    float64
#  25  qb2_value_post  187 non-null    float64
#  26  qbelo1_post     187 non-null    float64
#  27  qbelo2_post     187 non-null    float64
#  28  score1          187 non-null    int64
#  29  score2          187 non-null    int64
# dtypes: float64(20), int64(4), str(6)
# memory usage: 50.9 KB
# None
# date                0
# season              0
# neutral             0
# playoff           176
# team1               0
# team2               0
# elo1_pre            0
# elo2_pre            0
# elo_prob1           0
# elo_prob2           0
# elo1_post           0
# elo2_post           0
# qbelo1_pre          0
# qbelo2_pre          0
# qb1                 0
# qb2                 0
# qb1_value_pre       0
# qb2_value_pre       0
# qb1_adj             0
# qb2_adj             0
# qbelo_prob1         0
# qbelo_prob2         0
# qb1_game_value      0
# qb2_game_value      0
# qb1_value_post      0
# qb2_value_post      0
# qbelo1_post         0
# qbelo2_post         0
# score1              0
# score2              0
# dtype: int64

# %%
df = df.dropna()

# %%
target = "Result"

# %%
for col in df.select_dtypes(include=["object", "string"]).columns:
    if col != target:
        le = LabelEncoder()
        df[col] = le.fit_transform(df[col])
        label_encoders[col] = le

# %%
print(df.columns.tolist())
# Out:
# ['date', 'season', 'neutral', 'playoff', 'team1', 'team2', 'elo1_pre', 'elo2_pre', 'elo_prob1', 'elo_prob2', 'elo1_post', 'elo2_post', 'qbelo1_pre', 'qbelo2_pre', 'qb1', 'qb2', 'qb1_value_pre', 'qb2_value_pre', 'qb1_adj', 'qb2_adj', 'qbelo_prob1', 'qbelo_prob2', 'qb1_game_value', 'qb2_game_value', 'qb1_value_post', 'qb2_value_post', 'qbelo1_post', 'qbelo2_post', 'score1', 'score2']

# %%
print(df.columns)
# Out:
# Index(['date', 'season', 'neutral', 'playoff', 'team1', 'team2', 'elo1_pre',
#        'elo2_pre', 'elo_prob1', 'elo_prob2', 'elo1_post', 'elo2_post',
#        'qbelo1_pre', 'qbelo2_pre', 'qb1', 'qb2', 'qb1_value_pre',
#        'qb2_value_pre', 'qb1_adj', 'qb2_adj', 'qbelo_prob1', 'qbelo_prob2',
#        'qb1_game_value', 'qb2_game_value', 'qb1_value_post', 'qb2_value_post',
#        'qbelo1_post', 'qbelo2_post', 'score1', 'score2'],
#       dtype='str')

# %%
print(df.columns)
# Out:
# Index(['date', 'season', 'neutral', 'playoff', 'team1', 'team2', 'elo1_pre',
#        'elo2_pre', 'elo_prob1', 'elo_prob2', 'elo1_post', 'elo2_post',
#        'qbelo1_pre', 'qbelo2_pre', 'qb1', 'qb2', 'qb1_value_pre',
#        'qb2_value_pre', 'qb1_adj', 'qb2_adj', 'qbelo_prob1', 'qbelo_prob2',
#        'qb1_game_value', 'qb2_game_value', 'qb1_value_post', 'qb2_value_post',
#        'qbelo1_post', 'qbelo2_post', 'score1', 'score2'],
#       dtype='str')

# %%
print(df.head())
print(df.columns)
# Out:
#      date  season  neutral  playoff  ...  qbelo1_post  qbelo2_post  score1  score2
# 8       3    2006        0        2  ...  1599.594849  1493.121085      23      20
# 41      5    2010        0        2  ...  1552.739236  1652.634772      16      21
# 66      1    2013        0        2  ...  1554.695477  1614.164585      24      26
# 99      8    2017        0        1  ...  1659.769939  1636.942350      15      10
# 100    10    2017        0        0  ...  1697.116549  1654.501639      38       7
#
# [5 rows x 30 columns]
# Index(['date', 'season', 'neutral', 'playoff', 'team1', 'team2', 'elo1_pre',
#        'elo2_pre', 'elo_prob1', 'elo_prob2', 'elo1_post', 'elo2_post',
#        'qbelo1_pre', 'qbelo2_pre', 'qb1', 'qb2', 'qb1_value_pre',
#        'qb2_value_pre', 'qb1_adj', 'qb2_adj', 'qbelo_prob1', 'qbelo_prob2',
#        'qb1_game_value', 'qb2_game_value', 'qb1_value_post', 'qb2_value_post',
#        'qbelo1_post', 'qbelo2_post', 'score1', 'score2'],
#       dtype='str')
