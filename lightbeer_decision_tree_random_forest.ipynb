# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("LightBeer.csv")

df.head()
# Out:
#    household   upc_description  quantity beer_brand  beer_spend  beer_floz  \
# 0    2000946  BUD LT BR CN 12P         1  BUD LIGHT        8.14      144.0
# 1    2003036  BUD LT BR CN 24P         1  BUD LIGHT       17.48      288.0
# 2    2003036  BUD LT BR CN 24P         2  BUD LIGHT       33.92      576.0
# 3    2003036  BUD LT BR CN 30P         2  BUD LIGHT       34.74      720.0
# 4    2003036  BUD LT BR CN 36P         2  BUD LIGHT       40.48      864.0
#
#    price_floz container_descr  promotion          market  ...  age employment  \
# 0    0.056528             CAN      False  RURAL ILLINOIS  ...  50+       none
# 1    0.060694             CAN      False         ATLANTA  ...  50+       full
# 2    0.058889             CAN      False         ATLANTA  ...  50+       full
# 3    0.048250             CAN      False         ATLANTA  ...  50+       full
# 4    0.046852             CAN      False         ATLANTA  ...  50+       full
#
#     degree              occupation ethnic microwave dishwasher  tvcable  \
# 0     Grad    none/retired/student  white      True       True  premium
# 1  College  clerical/sales/service  white      True       True    basic
# 2  College  clerical/sales/service  white      True       True    basic
# 3  College  clerical/sales/service  white      True       True    basic
# 4  College  clerical/sales/service  white      True       True    basic
#
#   singlefamilyhome  npeople
# 0            False        1
# 1             True        2
# 2             True        2
# 3             True        2
# 4             True        2
#
# [5 rows x 24 columns]

# %%
print(df.info())
print(df.describe())
print(df.isnull().sum())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 73115 entries, 0 to 73114
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   household         73115 non-null  int64
#  1   upc_description   73115 non-null  str
#  2   quantity          73115 non-null  int64
#  3   beer_brand        73115 non-null  str
#  4   beer_spend        73115 non-null  float64
#  5   beer_floz         73115 non-null  float64
#  6   price_floz        73115 non-null  float64
#  7   container_descr   73115 non-null  str
#  8   promotion         73115 non-null  bool
#  9   market            73115 non-null  str
#  10  buyertype         73115 non-null  str
#  11  income            73115 non-null  str
#  12  childrenUnder6    73115 non-null  bool
#  13  children6to17     73115 non-null  bool
#  14  age               73115 non-null  str
#  15  employment        73115 non-null  str
#  16  degree            73115 non-null  str
#  17  occupation        73115 non-null  str
#  18  ethnic            73115 non-null  str
#  19  microwave         73115 non-null  bool
#  20  dishwasher        73115 non-null  bool
#  21  tvcable           73115 non-null  str
#  22  singlefamilyhome  73115 non-null  bool
#  23  npeople           73115 non-null  str
# dtypes: bool(6), float64(3), int64(2), str(13)
# memory usage: 17.3 MB
# None
#           household      quantity    beer_spend     beer_floz    price_floz
# count  7.311500e+04  73115.000000  73115.000000  73115.000000  73115.000000
# mean   1.740772e+07      1.317527     13.777683    265.926853      0.055951
# std    1.158215e+07      1.149649      8.722942    199.522488      0.013417
# min    2.000235e+06      1.000000      0.510000     12.000000      0.001315
# 25%    8.223438e+06      1.000000      8.970000    144.000000      0.046306
# 50%    8.413624e+06      1.000000     12.990000    216.000000      0.055509
# 75%    3.017132e+07      1.000000     16.380000    360.000000      0.063750
# max    3.044072e+07     48.000000    159.130000   9216.000000      0.234063
# household           0
# upc_description     0
# quantity            0
# beer_brand          0
# beer_spend          0
# beer_floz           0
# price_floz          0
# container_descr     0
# promotion           0
# market              0
# buyertype           0
# income              0
# childrenUnder6      0
# children6to17       0
# age                 0
# employment          0
# degree              0
# occupation          0
# ethnic              0
# microwave           0
# dishwasher          0
# tvcable             0
# singlefamilyhome    0
# npeople             0
# dtype: int64

# %%
df = df.dropna()  # simple approach (you can improve later)

# %%
from sklearn.preprocessing import LabelEncoder

for col in df.select_dtypes(include=['object', 'string']).columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])

# %%
print("Columns:", df.columns.tolist())
print("Contains 'target'? ->", "target" in df.columns)
# Out:
# Columns: ['household', 'upc_description', 'quantity', 'beer_brand', 'beer_spend', 'beer_floz', 'price_floz', 'container_descr', 'promotion', 'market', 'buyertype', 'income', 'childrenUnder6', 'children6to17', 'age', 'employment', 'degree', 'occupation', 'ethnic', 'microwave', 'dishwasher', 'tvcable', 'singlefamilyhome', 'npeople']
# Contains 'target'? -> False

# %%
print(df.columns)
# Out:
# Index(['household', 'upc_description', 'quantity', 'beer_brand', 'beer_spend',
#        'beer_floz', 'price_floz', 'container_descr', 'promotion', 'market',
#        'buyertype', 'income', 'childrenUnder6', 'children6to17', 'age',
#        'employment', 'degree', 'occupation', 'ethnic', 'microwave',
#        'dishwasher', 'tvcable', 'singlefamilyhome', 'npeople'],
#       dtype='str')

# %%
print(dir())
# Out:
# ['DecisionTreeClassifier', 'In', 'LabelEncoder', 'Out', 'RandomForestClassifier', '_', '_2', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__session__', '__spec__', '_dh', '_i', '_i1', '_i10', '_i11', '_i12', '_i13', '_i14', '_i15', '_i16', '_i2', '_i3', '_i4', '_i5', '_i6', '_i7', '_i8', '_i9', '_ih', '_ii', '_iii', '_oh', 'accuracy_score', 'classification_report', 'col', 'confusion_matrix', 'df', 'dt_model', 'exit', 'get_ipython', 'le', 'np', 'open', 'pd', 'plt', 'quit', 'sns', 'train_test_split']
