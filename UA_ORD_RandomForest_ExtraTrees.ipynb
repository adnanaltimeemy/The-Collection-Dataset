# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import LabelEncoder

# %%
# Load dataset
df = pd.read_csv("UA-ORD.csv")

# View basic info
print(df.head())
print(df.info())
print(df.describe())
# Out:
#          Date  ASM_Domestic  ...  RPM_Domestic  RPM_International
# 0  2002-10-01       1510047  ...       1071338           432226.0
# 1  2002-11-01       1376289  ...        953696           382371.0
# 2  2002-12-01       1431068  ...       1103849           430894.0
# 3  2003-01-01       1361921  ...        931486           378222.0
# 4  2003-02-01       1220918  ...        894857           315357.0
#
# [5 rows x 9 columns]
# <class 'pandas.DataFrame'>
# RangeIndex: 174 entries, 0 to 173
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      174 non-null    str
#  1   ASM_Domestic              174 non-null    int64
#  2   ASM_International         171 non-null    float64
#  3   Flights_Domestic          174 non-null    int64
#  4   Flights_International     171 non-null    float64
#  5   Passengers_Domestic       174 non-null    int64
#  6   Passengers_International  171 non-null    float64
#  7   RPM_Domestic              174 non-null    int64
#  8   RPM_International         171 non-null    float64
# dtypes: float64(4), int64(4), str(1)
# memory usage: 14.1 KB
# None
#        ASM_Domestic  ASM_International  ...  RPM_Domestic  RPM_International
# count  1.740000e+02         171.000000  ...  1.740000e+02         171.000000
# mean   1.038298e+06      619409.450292  ...  8.610246e+05      496012.818713
# std    2.171153e+05       79515.950052  ...  1.631782e+05       80027.093601
# min    6.700800e+05      314045.000000  ...  5.569510e+05      210163.000000
# 25%    8.607828e+05      569397.000000  ...  7.274645e+05      447387.500000
# 50%    9.916075e+05      614581.000000  ...  8.407025e+05      495428.000000
# 75%    1.241739e+06      678134.000000  ...  9.922722e+05      550713.500000
# max    1.540220e+06      789903.000000  ...  1.275844e+06      678177.000000
#
# [8 rows x 8 columns]

# %%
cat_cols = df.select_dtypes(include=['object', 'string']).columns

label_encoders = {}

for col in cat_cols:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col].astype(str))
    label_encoders[col] = le

# %%
[df.columns]
df.head()
# Out:
#    Date  ASM_Domestic  ...  RPM_Domestic  RPM_International
# 0     0       1510047  ...       1071338           432226.0
# 1     1       1376289  ...        953696           382371.0
# 2     2       1431068  ...       1103849           430894.0
# 3     3       1361921  ...        931486           378222.0
# 4     4       1220918  ...        894857           315357.0
#
# [5 rows x 9 columns]

# %%
print(df.columns)
# Out:
# Index(['Date', 'ASM_Domestic', 'ASM_International', 'Flights_Domestic',
#        'Flights_International', 'Passengers_Domestic',
#        'Passengers_International', 'RPM_Domestic', 'RPM_International'],
#       dtype='str')

# %%
print("X_train exists:", "X_train" in globals())
print("X exists:", "X" in globals())
print("y exists:", "y" in globals())
# Out:
# X_train exists: False
# X exists: False
# y exists: False

# %%
df.head()
df.columns
# Out:
# Index(['Date', 'ASM_Domestic', 'ASM_International', 'Flights_Domestic',
#        'Flights_International', 'Passengers_Domestic',
#        'Passengers_International', 'RPM_Domestic', 'RPM_International'],
#       dtype='str')

# %%
print(df.head())
# Out:
#    Date  ASM_Domestic  ...  RPM_Domestic  RPM_International
# 0     0       1510047  ...       1071338           432226.0
# 1     1       1376289  ...        953696           382371.0
# 2     2       1431068  ...       1103849           430894.0
# 3     3       1361921  ...        931486           378222.0
# 4     4       1220918  ...        894857           315357.0
#
# [5 rows x 9 columns]
