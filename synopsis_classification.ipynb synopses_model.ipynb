# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import classification_report, accuracy_score

# %%
df = pd.read_csv("synopses.csv")

df.head()
# Out:
#                show                                           synopsis
# 0       42nd Street  A chorus girl from Allentown, PA, steps into t...
# 1     A Chorus Line  Broadway gypsies bare their souls and put thei...
# 2    Aren't We All?  English nobility seek out marriage proposals —...
# 3  Arms and the Man                                                NaN
# 4             As Is                                                NaN

# %%
print(df.columns)
print(df.isnull().sum())
# Out:
# Index(['show', 'synopsis'], dtype='str')
# show          0
# synopsis    177
# dtype: int64

# %%
df = df.dropna()

# %%
print("Columns:", df.columns.tolist())
print(df.head())
# Out:
# Columns: ['show', 'synopsis']
#              show                                           synopsis
# 0     42nd Street  A chorus girl from Allentown, PA, steps into t...
# 1   A Chorus Line  Broadway gypsies bare their souls and put thei...
# 2  Aren't We All?  English nobility seek out marriage proposals —...
# 5       Big River  In Roger Miller and William Hauptman's musical...
# 6    Biloxi Blues  In the second installment of Neil Simon's auto...

# %%
print(df.columns)
# Out:
# Index(['show', 'synopsis'], dtype='str')

# %%
print("X_train exists:", "X_train" in globals())
# Out:
# X_train exists: False

# %%
print("X_train_vec" in globals())
# Out:
# False

# %%
print(globals().keys())
# Out:
# dict_keys(['__name__', '__doc__', '__package__', '__loader__', '__spec__', '__builtin__', '__builtins__', '_ih', '_oh', '_dh', 'In', 'Out', 'get_ipython', 'exit', 'quit', 'open', '_', '__', '___', '__session__', '_i', '_ii', '_iii', '_i1', 'pd', 'np', 'train_test_split', 'TfidfVectorizer', 'DecisionTreeClassifier', 'RandomForestClassifier', 'classification_report', 'accuracy_score', '_i2', 'df', '_2', '_i3', '_i4', '_i5', 'X', '_i6', '_i7', '_i8', '_i9', '_i10', 'vectorizer', '_i11', '_i12', '_i13', 'dt_model', '_i14', '_i15', 'rf_model', '_i16', '_i17'])

# %%
print(hasattr(vectorizer, "vocabulary_"))
# Out:
# False
