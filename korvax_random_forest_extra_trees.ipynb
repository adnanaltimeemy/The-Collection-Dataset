# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer

from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
df = pd.read_csv("dictionary-korvax.csv")

df.head()
# Out:
#          Korvax English
# 0           akh     NaN
# 1         amcha     NaN
# 2          arus     NaN
# 3  ayevskovkazh     NaN
# 4      bokhodim     NaN

# %%
print(df.shape)
print(df.info())
print(df.describe())
# Out:
# (67, 2)
# <class 'pandas.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Korvax   67 non-null     str
#  1   English  2 non-null      str
# dtypes: str(2)
# memory usage: 1.7 KB
# None
#        Korvax    English
# count      67          2
# unique     67          1
# top       akh  traveller
# freq        1          2

# %%
print(df.select_dtypes(include=np.number).shape)
print(df.select_dtypes(include=np.number).columns)
# Out:
# (67, 0)
# Index([], dtype='str')

# %%
cat_cols = df.select_dtypes(include=['object', 'category', 'string']).columns

# %%
df.columns = df.columns.str.strip()

# %%
print(df.head())
# Out:
#    Korvax  English
# 0       0        1
# 1       1        1
# 2       2        1
# 3       3        1
# 4       4        1

# %%
print([col for col in df.columns if "target" in col.lower()])
# Out:
# []

# %%
import numpy as np

X = np.array([...])  # features
y = np.array([...])  # labels

# %%
print(type(X), type(y))
print(X.shape, y.shape)
# Out:
# <class 'numpy.ndarray'> <class 'numpy.ndarray'>
# (1,) (1,)

# %%
df.head()
df.columns
# Out:
# Index(['Korvax', 'English'], dtype='str')
