# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report

from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier

# %%
df = pd.read_csv("weapons.csv")

df.head()
# Out:
#       Slot  ...                                        Description
# 0  Primary  ...  5.56mm light carbine. Standard model with the ...
# 1  Primary  ...  Soviet 5.56mm assault rifle. Its stability and...
# 2  Primary  ...  7.62mm full-length assault rifle. Its precisio...
# 3  Primary  ...  Automatic Shotgun. Combines the power of a tra...
# 4  Primary  ...  Caseless grenade launcher. The simplified cons...
#
# [5 rows x 5 columns]

# %%
print(df.shape)
print(df.info())
print(df.describe())
print(df.isnull().sum())
# Out:
# (23, 5)
# <class 'pandas.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Slot         23 non-null     str
#  1   Type         23 non-null     str
#  2   Name         23 non-null     str
#  3   Title        11 non-null     str
#  4   Description  11 non-null     str
# dtypes: str(5)
# memory usage: 3.7 KB
# None
#            Slot  ...                                        Description
# count        23  ...                                                 11
# unique        2  ...                                                 11
# top     Primary  ...  5.56mm light carbine. Standard model with the ...
# freq         13  ...                                                  1
#
# [4 rows x 5 columns]
# Slot            0
# Type            0
# Name            0
# Title          12
# Description    12
# dtype: int64

# %%
df = df.dropna()

# %%
for col in df.columns:
    print(repr(col))
# Out:
# 'Slot'
# 'Type'
# 'Name'
# 'Title'
# 'Description'

# %%
print(df.columns.tolist())
# Out:
# ['Slot', 'Type', 'Name', 'Title', 'Description']

# %%
df.columns
df.head()
# Out:
#       Slot  ...                                        Description
# 0  Primary  ...  5.56mm light carbine. Standard model with the ...
# 1  Primary  ...  Soviet 5.56mm assault rifle. Its stability and...
# 2  Primary  ...  7.62mm full-length assault rifle. Its precisio...
# 3  Primary  ...  Automatic Shotgun. Combines the power of a tra...
# 4  Primary  ...  Caseless grenade launcher. The simplified cons...
#
# [5 rows x 5 columns]

# %%
print(globals().keys())
# Out:
# dict_keys(['__name__', '__doc__', '__package__', '__loader__', '__spec__', '__builtin__', '__builtins__', '_ih', '_oh', '_dh', 'In', 'Out', 'get_ipython', 'exit', 'quit', 'open', '_', '__', '___', '__session__', '_i', '_ii', '_iii', '_i1', 'pd', 'np', 'train_test_split', 'LabelEncoder', 'accuracy_score', 'classification_report', 'RandomForestClassifier', 'ExtraTreesClassifier', '_i2', 'df', '_2', '_i3', '_i4', '_i5', '_i6', '_i7', 'col', '_i8', '_i9', '_i10', '_i11', '_11', '_i12', 'plt', '_i13', '_i14'])

# %%
print(df.head())
print(df.columns)
# Out:
#       Slot  ...                                        Description
# 0  Primary  ...  5.56mm light carbine. Standard model with the ...
# 1  Primary  ...  Soviet 5.56mm assault rifle. Its stability and...
# 2  Primary  ...  7.62mm full-length assault rifle. Its precisio...
# 3  Primary  ...  Automatic Shotgun. Combines the power of a tra...
# 4  Primary  ...  Caseless grenade launcher. The simplified cons...
#
# [5 rows x 5 columns]
# Index(['Slot', 'Type', 'Name', 'Title', 'Description'], dtype='str')
