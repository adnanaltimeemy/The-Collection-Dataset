# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("AA-DFW.csv")

# Quick look at data
print(df.head())
print(df.info())
print(df.describe())
# Out:
#          Date  ASM_Domestic  ...  RPM_Domestic  RPM_International
# 0  2002-10-01       1743807  ...       1201010           304759.0
# 1  2002-11-01       1594750  ...       1038874           290464.0
# 2  2002-12-01       1669405  ...       1226770           343228.0
# 3  2003-01-01       1635626  ...       1049177           313166.0
# 4  2003-02-01       1411991  ...        958878           271608.0
#
# [5 rows x 9 columns]
# <class 'pandas.DataFrame'>
# RangeIndex: 174 entries, 0 to 173
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      174 non-null    str
#  1   ASM_Domestic              174 non-null    int64
#  2   ASM_International         171 non-null    float64
#  3   Flights_Domestic          174 non-null    int64
#  4   Flights_International     171 non-null    float64
#  5   Passengers_Domestic       174 non-null    int64
#  6   Passengers_International  171 non-null    float64
#  7   RPM_Domestic              174 non-null    int64
#  8   RPM_International         171 non-null    float64
# dtypes: float64(4), int64(4), str(1)
# memory usage: 14.1 KB
# None
#        ASM_Domestic  ASM_International  ...  RPM_Domestic  RPM_International
# count  1.740000e+02         171.000000  ...  1.740000e+02         171.000000
# mean   1.802498e+06      614842.625731  ...  1.477320e+06      478534.356725
# std    1.105922e+05      130332.342682  ...  1.530506e+05      116370.554273
# min    1.411991e+06      395426.000000  ...  9.588780e+05      266840.000000
# 25%    1.740433e+06      522825.500000  ...  1.381876e+06      398767.000000
# 50%    1.802374e+06      579073.000000  ...  1.491743e+06      446791.000000
# 75%    1.879132e+06      664025.500000  ...  1.582845e+06      534046.500000
# max    2.113573e+06      939827.000000  ...  1.841778e+06      784922.000000
#
# [8 rows x 8 columns]

# %%
from sklearn.preprocessing import LabelEncoder

for col in df.select_dtypes(include=['object', 'string']).columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col].astype(str))

# %%
df.columns = df.columns.str.strip()

# %%
print(df.head())
print(df.columns)
# Out:
#    Date  ASM_Domestic  ...  RPM_Domestic  RPM_International
# 0     0       1743807  ...       1201010           304759.0
# 1     1       1594750  ...       1038874           290464.0
# 2     2       1669405  ...       1226770           343228.0
# 3     3       1635626  ...       1049177           313166.0
# 4     4       1411991  ...        958878           271608.0
#
# [5 rows x 9 columns]
# Index(['Date', 'ASM_Domestic', 'ASM_International', 'Flights_Domestic',
#        'Flights_International', 'Passengers_Domestic',
#        'Passengers_International', 'RPM_Domestic', 'RPM_International'],
#       dtype='str')

# %%
from sklearn.datasets import load_iris

data = load_iris()
X = data.data
y = data.target

# %%
print(df.head)
# Out:
# <bound method NDFrame.head of      Date  ASM_Domestic  ...  RPM_Domestic  RPM_International
# 0       0       1743807  ...       1201010           304759.0
# 1       1       1594750  ...       1038874           290464.0
# 2       2       1669405  ...       1226770           343228.0
# 3       3       1635626  ...       1049177           313166.0
# 4       4       1411991  ...        958878           271608.0
# ..    ...           ...  ...           ...                ...
# 166   166       1917191  ...       1580186           705782.0
# 167   167       1828606  ...       1559901           674704.0
# 168   168       1849588  ...       1571483           710952.0
# 169   169       1768222  ...       1478966           626845.0
# 170   170       1840786  ...       1531917           745812.0
#
# [171 rows x 9 columns]>
