# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("dictionary-gek.csv")

# Preview data
print(df.head())
print(df.info())
# Out:
#              Gek English
# 0           Acer     NaN
# 1           Ammr     NaN
# 2  Ardennelmarki     NaN
# 3       Asafntin     NaN
# 4     Asgautenha     NaN
# <class 'pandas.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Gek      96 non-null     str
#  1   English  6 non-null      str
# dtypes: str(2)
# memory usage: 2.3 KB
# None

# %%
# Drop duplicates if any
df = df.drop_duplicates()

# Handle missing values (simple strategy)
df = df.dropna()

# %%
print(df.head())
# Out:
#          Gek   English
# 10     Buyrg       Joy
# 28       Hei       Gek
# 40   Kivendi   Trading
# 43  Lefabeig  Starship
# 75     Sritz     Units

# %%
print(df.head())
print(df.columns)
# Out:
#          Gek   English
# 10     Buyrg       Joy
# 28       Hei       Gek
# 40   Kivendi   Trading
# 43  Lefabeig  Starship
# 75     Sritz     Units
# Index(['Gek', 'English'], dtype='str')

# %%
print(df.head())
print(df.columns)
# Out:
#              Gek English
# 0           Acer     NaN
# 1           Ammr     NaN
# 2  Ardennelmarki     NaN
# 3       Asafntin     NaN
# 4     Asgautenha     NaN
# Index(['Gek', 'English'], dtype='str')

# %%
print(df.columns)
# Out:
# Index(['Gek', 'English'], dtype='str')

# %%
'rf_model' in globals()
# Out:
# False
