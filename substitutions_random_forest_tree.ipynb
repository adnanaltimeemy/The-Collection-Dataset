# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report

from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.read_csv("substitutions.csv")

df.head()
# Out:
#    key_id substitution_id tournament_id  ... match_period going_off coming_on
# 0       1          S-0001       WC-1970  ...  second half         1         0
# 1       2          S-0002       WC-1970  ...  second half         0         1
# 2       3          S-0003       WC-1970  ...  second half         1         0
# 3       4          S-0004       WC-1970  ...  second half         0         1
# 4       5          S-0005       WC-1970  ...  second half         1         0
#
# [5 rows x 24 columns]

# %%
print(df.shape)
print(df.info())
print(df.isnull().sum())
# Out:
# (10222, 24)
# <class 'pandas.DataFrame'>
# RangeIndex: 10222 entries, 0 to 10221
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   key_id             10222 non-null  int64
#  1   substitution_id    10222 non-null  str
#  2   tournament_id      10222 non-null  str
#  3   tournament_name    10222 non-null  str
#  4   match_id           10222 non-null  str
#  5   match_name         10222 non-null  str
#  6   match_date         10222 non-null  str
#  7   stage_name         10222 non-null  str
#  8   group_name         10222 non-null  str
#  9   team_id            10222 non-null  str
#  10  team_name          10222 non-null  str
#  11  team_code          10222 non-null  str
#  12  home_team          10222 non-null  int64
#  13  away_team          10222 non-null  int64
#  14  player_id          10222 non-null  str
#  15  family_name        10222 non-null  str
# ...

# %%
df = df.dropna()  # simple approach; you can improve with imputation if needed

# %%
for col in df.select_dtypes(include=['object', 'string[python]']).columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col].astype(str))
    label_encoders[col] = le

# %%
print("target" in df.columns)
# Out:
# False

# %%
print([col for col in df.columns])
# Out:
# ['key_id', 'substitution_id', 'tournament_id', 'tournament_name', 'match_id', 'match_name', 'match_date', 'stage_name', 'group_name', 'team_id', 'team_name', 'team_code', 'home_team', 'away_team', 'player_id', 'family_name', 'given_name', 'shirt_number', 'minute_label', 'minute_regulation', 'minute_stoppage', 'match_period', 'going_off', 'coming_on']

# %%
print(df.columns)
# Out:
# Index(['key_id', 'substitution_id', 'tournament_id', 'tournament_name',
#        'match_id', 'match_name', 'match_date', 'stage_name', 'group_name',
#        'team_id', 'team_name', 'team_code', 'home_team', 'away_team',
#        'player_id', 'family_name', 'given_name', 'shirt_number',
#        'minute_label', 'minute_regulation', 'minute_stoppage', 'match_period',
#        'going_off', 'coming_on'],
#       dtype='str')

# %%
print(df.head())
print(df.columns.tolist())
# Out:
#    key_id  substitution_id  tournament_id  ...  match_period  going_off  coming_on
# 0       1                0              0  ...             6          1          0
# 1       2                1              0  ...             6          0          1
# 2       3                2              0  ...             6          1          0
# 3       4                3              0  ...             6          0          1
# 4       5                4              0  ...             6          1          0
#
# [5 rows x 24 columns]
# ['key_id', 'substitution_id', 'tournament_id', 'tournament_name', 'match_id', 'match_name', 'match_date', 'stage_name', 'group_name', 'team_id', 'team_name', 'team_code', 'home_team', 'away_team', 'player_id', 'family_name', 'given_name', 'shirt_number', 'minute_label', 'minute_regulation', 'minute_stoppage', 'match_period', 'going_off', 'coming_on']

# %%
df.head()
df.columns
# Out:
# Index(['key_id', 'substitution_id', 'tournament_id', 'tournament_name',
#        'match_id', 'match_name', 'match_date', 'stage_name', 'group_name',
#        'team_id', 'team_name', 'team_code', 'home_team', 'away_team',
#        'player_id', 'family_name', 'given_name', 'shirt_number',
#        'minute_label', 'minute_regulation', 'minute_stoppage', 'match_period',
#        'going_off', 'coming_on'],
#       dtype='str')

# %%
df.head()
# Out:
#    key_id  substitution_id  tournament_id  ...  match_period  going_off  coming_on
# 0       1                0              0  ...             6          1          0
# 1       2                1              0  ...             6          0          1
# 2       3                2              0  ...             6          1          0
# 3       4                3              0  ...             6          0          1
# 4       5                4              0  ...             6          1          0
#
# [5 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10222 entries, 0 to 10221
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   key_id             10222 non-null  int64
#  1   substitution_id    10222 non-null  int64
#  2   tournament_id      10222 non-null  int64
#  3   tournament_name    10222 non-null  int64
#  4   match_id           10222 non-null  int64
#  5   match_name         10222 non-null  int64
#  6   match_date         10222 non-null  int64
#  7   stage_name         10222 non-null  int64
#  8   group_name         10222 non-null  int64
#  9   team_id            10222 non-null  int64
#  10  team_name          10222 non-null  int64
#  11  team_code          10222 non-null  int64
#  12  home_team          10222 non-null  int64
#  13  away_team          10222 non-null  int64
#  14  player_id          10222 non-null  int64
#  15  family_name        10222 non-null  int64
# ...

# %%
print(df.columns)
# Out:
# Index(['key_id', 'substitution_id', 'tournament_id', 'tournament_name',
#        'match_id', 'match_name', 'match_date', 'stage_name', 'group_name',
#        'team_id', 'team_name', 'team_code', 'home_team', 'away_team',
#        'player_id', 'family_name', 'given_name', 'shirt_number',
#        'minute_label', 'minute_regulation', 'minute_stoppage', 'match_period',
#        'going_off', 'coming_on'],
#       dtype='str')

# %%
print(df.head())
# Out:
#    key_id  substitution_id  tournament_id  ...  match_period  going_off  coming_on
# 0       1                0              0  ...             6          1          0
# 1       2                1              0  ...             6          0          1
# 2       3                2              0  ...             6          1          0
# 3       4                3              0  ...             6          0          1
# 4       5                4              0  ...             6          1          0
#
# [5 rows x 24 columns]

# %%
print([name for name in globals() if "test" in name])
# Out:
# ['train_test_split']
