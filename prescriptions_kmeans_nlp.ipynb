# %%
import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

import matplotlib.pyplot as plt
import seaborn as sns

import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/adnanaltimeemy/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = pd.read_csv("prescriptions.csv")

df.head()
# Out:
#    Unnamed: 0 prescriber_id  num_opioid_prescriptions  num_prescriptions
# 0           0   BDRSDDB2&RA                         4                  7
# 1           1   3$N3WG4&BBO                        25                 28
# 2           2   S2NGGOGBRB4                         1                  1
# 3           3   S2NGGOGBRB4                        18                 22
# 4           4   NBORABOESOI                         1                  1

# %%
df = df.dropna()

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'prescriber_id', 'num_opioid_prescriptions',
#        'num_prescriptions'],
#       dtype='str')

# %%
if text_column not in df.columns:
    print("Column not found:", text_column)
# Out:
# Column not found: review

# %%
import numpy as np

X = np.array([
    [1, 2],
    [3, 4],
    [5, 6]
])

# %%
df.head()
# Out:
#    Unnamed: 0 prescriber_id  num_opioid_prescriptions  num_prescriptions
# 0           0   BDRSDDB2&RA                         4                  7
# 1           1   3$N3WG4&BBO                        25                 28
# 2           2   S2NGGOGBRB4                         1                  1
# 3           3   S2NGGOGBRB4                        18                 22
# 4           4   NBORABOESOI                         1                  1

# %%
type(X)
# Out:
# numpy.ndarray

# %%
print("X shape:", X.shape)
print("Reduced shape:", reduced.shape)
print("DF shape:", df.shape)
# Out:
# X shape: (3, 2)
# Reduced shape: (3, 2)
# DF shape: (150, 4)

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'prescriber_id', 'num_opioid_prescriptions',
#        'num_prescriptions'],
#       dtype='str')

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'prescriber_id', 'num_opioid_prescriptions',
#        'num_prescriptions'],
#       dtype='str')

# %%
df.head()
# Out:
#    Unnamed: 0 prescriber_id  num_opioid_prescriptions  num_prescriptions
# 0           0   BDRSDDB2&RA                         4                  7
# 1           1   3$N3WG4&BBO                        25                 28
# 2           2   S2NGGOGBRB4                         1                  1
# 3           3   S2NGGOGBRB4                        18                 22
# 4           4   NBORABOESOI                         1                  1
