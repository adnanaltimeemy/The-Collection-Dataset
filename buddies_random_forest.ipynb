# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv("buddies.csv")

print(df.head())
print(df.info())
# Out:
#       Buddy  Unnamed: 1
# 0   D-Horse         NaN
# 1     D-Dog         NaN
# 2     Quiet         NaN
# 3  D-Walker         NaN
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Buddy       4 non-null      str
#  1   Unnamed: 1  0 non-null      float64
# dtypes: float64(1), str(1)
# memory usage: 221.0 bytes
# None

# %%
# Drop missing values (simple approach)
df = df.dropna()

# If you have categorical columns, convert them
df = pd.get_dummies(df, drop_first=True)

# %%
if "target" in df.columns:
    X = df.drop("target", axis=1)
    y = df["target"]
else:
    print("Column 'target' not found:", df.columns)
# Out:
# Column 'target' not found: Index(['Unnamed: 1'], dtype='str')

# %%
X = df.iloc[:, :-1]   # all columns except last
y = df.iloc[:, -1]    # last column

# %%
from sklearn.datasets import load_iris

data = load_iris()
X = data.data
y = data.target

# %%
hasattr(rf_model, "feature_importances_")
# Out:
# False
