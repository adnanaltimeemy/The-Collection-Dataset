# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv("NHL Games.csv")

df.head()
# Out:
#    GP      Date Unnamed: 2            Opponent  ...  OL  Streak Postseason Season
# 0   1  04-10-07          @      Calgary Flames  ...   0     W 1          0   2007
# 1   2  06-10-07          @     Edmonton Oilers  ...   0     L 1          0   2007
# 2   3  10-10-07          @   Vancouver Canucks  ...   0     W 1          0   2007
# 3   4  13-10-07        NaN  New York Islanders  ...   0     W 2          0   2007
# 4   5  16-10-07        NaN   Atlanta Thrashers  ...   0     W 3          0   2007
#
# [5 rows x 14 columns]

# %%
print(df.shape)
print(df.info())
print(df.describe())
# Out:
# (616, 14)
# <class 'pandas.DataFrame'>
# RangeIndex: 616 entries, 0 to 615
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   GP          616 non-null    int64
#  1   Date        616 non-null    str
#  2   Unnamed: 2  309 non-null    str
#  3   Opponent    616 non-null    str
#  4   GF          615 non-null    float64
#  5   GA          615 non-null    float64
#  6   Unnamed: 6  615 non-null    str
#  7   Unnamed: 7  125 non-null    str
#  8   W           615 non-null    float64
#  9   L           615 non-null    float64
#  10  OL          615 non-null    str
#  11  Streak      540 non-null    str
#  12  Postseason  616 non-null    int64
#  13  Season      616 non-null    int64
# dtypes: float64(4), int64(3), str(7)
# memory usage: 86.3 KB
# None
#                GP          GF          GA  ...           L  Postseason       Season
# count  616.000000  615.000000  615.000000  ...  615.000000  616.000000   616.000000
# mean    36.180195    3.040650    2.863415  ...   12.829268    0.121753  2009.806818
# std     24.491810    1.772015    1.672019  ...    8.676888    0.327266     1.983678
# min      1.000000    0.000000    0.000000  ...    0.000000    0.000000  2007.000000
# 25%     14.000000    2.000000    2.000000  ...    5.000000    0.000000  2008.000000
# 50%     34.000000    3.000000    3.000000  ...   12.000000    0.000000  2010.000000
# 75%     57.000000    4.000000    4.000000  ...   19.500000    0.000000  2011.000000
# max     83.000000    9.000000   10.000000  ...   35.000000    1.000000  2013.000000
#
# [8 rows x 7 columns]

# %%
df = df.dropna()   # simplest approach

# %%
print(list(df.columns))
# Out:
# ['GP', 'Date', 'Unnamed: 2', 'Opponent', 'GF', 'GA', 'Unnamed: 6', 'Unnamed: 7', 'W', 'L', 'OL', 'Streak', 'Postseason', 'Season']

# %%
X = df.copy()

# %%
print(df.columns)
# Out:
# Index(['GP', 'Date', 'Unnamed: 2', 'Opponent', 'GF', 'GA', 'Unnamed: 6',
#        'Unnamed: 7', 'W', 'L', 'OL', 'Streak', 'Postseason', 'Season'],
#       dtype='str')

# %%
print(df.columns)
print(df.head())
# Out:
# Index(['GP', 'Date', 'Unnamed: 2', 'Opponent', 'GF', 'GA', 'Unnamed: 6',
#        'Unnamed: 7', 'W', 'L', 'OL', 'Streak', 'Postseason', 'Season'],
#       dtype='str')
#     GP      Date Unnamed: 2             Opponent  ...  OL  Streak Postseason Season
# 59  60  19-02-08          @      Ottawa Senators  ...   6     L 8          0   2007
# 62  63  25-02-08          @       Buffalo Sabres  ...   7     W 1          0   2007
# 65  66  02-03-08          @     New York Rangers  ...   8     L 1          0   2007
# 69  70  11-03-08          @  Toronto Maple Leafs  ...   9     L 1          0   2007
# 71  72  15-03-08          @        Boston Bruins  ...  10     L 3          0   2007
#
# [5 rows x 14 columns]

# %%
print(df.columns)
# Out:
# Index(['GP', 'Date', 'Unnamed: 2', 'Opponent', 'GF', 'GA', 'Unnamed: 6',
#        'Unnamed: 7', 'W', 'L', 'OL', 'Streak', 'Postseason', 'Season'],
#       dtype='str')
