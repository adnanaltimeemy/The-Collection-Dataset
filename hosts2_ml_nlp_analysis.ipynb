# %%
import pandas as pd
import numpy as np

# ML models
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.cluster import KMeans

# NLP
from sklearn.feature_extraction.text import TfidfVectorizer

# Preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler

# Metrics
from sklearn.metrics import accuracy_score, classification_report

import matplotlib.pyplot as plt

# %%
df = pd.read_csv("hosts2.csv")

print(df.head())
print(df.info())
# Out:
#   redis1 KV 127.0.0.1 6379
# 0   l11 L1 127.0.0.1 10001
# 1   l12 L1 127.0.0.1 10002
# 2   l21 L2 127.0.0.1 11001
# 3   l22 L2 127.0.0.1 11002
# 4   l31 L3 127.0.0.1 13001
# <class 'pandas.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 1 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   redis1 KV 127.0.0.1 6379  6 non-null      str
# dtypes: str(1)
# memory usage: 312.0 bytes
# None

# %%
# Drop duplicates
df = df.drop_duplicates()

# Fill missing values
df = df.fillna("")

# %%
print(df.columns)
# Out:
# Index(['redis1 KV 127.0.0.1 6379'], dtype='str')

# %%
print(df.columns)
# Out:
# Index(['redis1 KV 127.0.0.1 6379'], dtype='str')

# %%
df.head()
# Out:
#   redis1 KV 127.0.0.1 6379
# 0   l11 L1 127.0.0.1 10001
# 1   l12 L1 127.0.0.1 10002
# 2   l21 L2 127.0.0.1 11001
# 3   l22 L2 127.0.0.1 11002
# 4   l31 L3 127.0.0.1 13001

# %%
print(df.columns)
# Out:
# Index(['redis1 KV 127.0.0.1 6379'], dtype='str')

# %%
df.head()
df.columns
# Out:
# Index(['redis1 KV 127.0.0.1 6379'], dtype='str')

# %%
print(df.columns)
# Out:
# Index(['redis1 KV 127.0.0.1 6379'], dtype='str')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# your raw text data (YOU must replace this with your dataset)
documents = [
    "apple banana fruit",
    "dog cat animal",
    "car bus transport",
    "banana orange fruit",
    "train car transport"
]

vectorizer = TfidfVectorizer()
X_text = vectorizer.fit_transform(documents)

# %%
print("y_test exists:", "y_test" in globals())
# Out:
# y_test exists: False

# %%
print("y_test" in globals())
# Out:
# False
