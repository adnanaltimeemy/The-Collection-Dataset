# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv("checkins.csv")

print(df.head())
print(df.info())
print(df.describe())
# Out:
#    checkin_id                       created_at  ... ratings_count  checkins_count
# 0   972632193  Tue, 08 Dec 2020 19:09:24 +0000  ...        8755.0         10789.0
# 1   972225431  Sun, 06 Dec 2020 21:49:46 +0000  ...        3078.0          3960.0
# 2   972224466  Sun, 06 Dec 2020 21:48:07 +0000  ...           0.0             1.0
# 3   971765224  Sat, 05 Dec 2020 23:04:03 +0000  ...          71.0            93.0
# 4   971635392  Sat, 05 Dec 2020 20:51:22 +0000  ...         486.0           543.0
#
# [5 rows x 29 columns]
# <class 'pandas.DataFrame'>
# RangeIndex: 2727 entries, 0 to 2726
# Data columns (total 29 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   checkin_id       2727 non-null   int64
#  1   created_at       2727 non-null   str
#  2   checkin_comment  301 non-null    str
#  3   rating_score     2727 non-null   float64
#  4   user_id          2727 non-null   int64
#  5   user_name        2727 non-null   str
#  6   beer_id          2727 non-null   int64
#  7   beer_name        2727 non-null   str
#  8   beer_style       2727 non-null   str
#  9   beer_slug        2727 non-null   str
#  10  beer_abv         2727 non-null   float64
#  11  beer_link        2727 non-null   str
#  12  brewery_id       2727 non-null   int64
#  13  brewery_name     2727 non-null   str
#  14  brewery_type     2727 non-null   str
#  15  brewery_country  2727 non-null   str
#  16  brewery_city     2473 non-null   str
#  17  brewery_link     2727 non-null   str
#  18  source_app       2727 non-null   str
#  19  toasts_count     2727 non-null   int64
#  20  venue_id         2715 non-null   float64
#  21  venue_name       2715 non-null   str
#  22  venue_country    2715 non-null   str
#  23  venue_city       2532 non-null   str
#  24  venue_lat        2715 non-null   float64
#  25  venue_lng        2715 non-null   float64
#  26  avg_rating       2697 non-null   float64
#  27  ratings_count    2727 non-null   float64
#  28  checkins_count   2727 non-null   float64
# dtypes: float64(8), int64(5), str(16)
# memory usage: 1.4 MB
# None
#          checkin_id  rating_score  ...  ratings_count  checkins_count
# count  2.727000e+03   2727.000000  ...    2727.000000    2.727000e+03
# mean   7.752371e+08      3.505684  ...   10998.596993    2.595830e+04
# std    1.312709e+08      0.888948  ...   63697.401530    1.985698e+05
# min    4.400218e+08      0.000000  ...       0.000000    1.000000e+00
# 25%    6.742378e+08      3.250000  ...     192.000000    2.180000e+02
# 50%    7.878380e+08      3.750000  ...     411.000000    4.850000e+02
# 75%    8.970508e+08      4.000000  ...    1414.500000    1.656500e+03
# max    9.726322e+08      4.750000  ...  692439.000000    2.430000e+06
#
# [8 rows x 13 columns]

# %%
# Check missing values
print(df.isnull().sum())

# Drop rows with missing values (simple approach)
df = df.dropna()
# Out:
# checkin_id            0
# created_at            0
# checkin_comment    2426
# rating_score          0
# user_id               0
# user_name             0
# beer_id               0
# beer_name             0
# beer_style            0
# beer_slug             0
# beer_abv              0
# beer_link             0
# brewery_id            0
# brewery_name          0
# brewery_type          0
# brewery_country       0
# brewery_city        254
# brewery_link          0
# source_app            0
# toasts_count          0
# venue_id             12
# venue_name           12
# venue_country        12
# venue_city          195
# venue_lat            12
# venue_lng            12
# avg_rating           30
# ratings_count         0
# checkins_count        0
# dtype: int64

# %%
print([col for col in df.columns if "target" in col.lower()])
# Out:
# []

# %%
df.columns = df.columns.str.strip()

# %%
print(type(df))
print(df.head())
# Out:
# <class 'pandas.DataFrame'>
#     checkin_id                       created_at  ... ratings_count  checkins_count
# 10   970949953  Fri, 04 Dec 2020 19:36:48 +0000  ...          55.0            61.0
# 12   970915252  Fri, 04 Dec 2020 18:49:03 +0000  ...        3328.0          4384.0
# 24   968856197  Sat, 28 Nov 2020 00:27:40 +0000  ...         129.0           144.0
# 26   968854851  Sat, 28 Nov 2020 00:25:37 +0000  ...         158.0           188.0
# 27   968758949  Fri, 27 Nov 2020 22:17:34 +0000  ...          91.0           125.0
#
# [5 rows x 29 columns]

# %%
print(df.columns)
# Out:
# Index(['checkin_id', 'created_at', 'checkin_comment', 'rating_score',
#        'user_id', 'user_name', 'beer_id', 'beer_name', 'beer_style',
#        'beer_slug', 'beer_abv', 'beer_link', 'brewery_id', 'brewery_name',
#        'brewery_type', 'brewery_country', 'brewery_city', 'brewery_link',
#        'source_app', 'toasts_count', 'venue_id', 'venue_name', 'venue_country',
#        'venue_city', 'venue_lat', 'venue_lng', 'avg_rating', 'ratings_count',
#        'checkins_count'],
#       dtype='str')

# %%
print(df.columns)
# Out:
# Index(['checkin_id', 'created_at', 'checkin_comment', 'rating_score',
#        'user_id', 'user_name', 'beer_id', 'beer_name', 'beer_style',
#        'beer_slug', 'beer_abv', 'beer_link', 'brewery_id', 'brewery_name',
#        'brewery_type', 'brewery_country', 'brewery_city', 'brewery_link',
#        'source_app', 'toasts_count', 'venue_id', 'venue_name', 'venue_country',
#        'venue_city', 'venue_lat', 'venue_lng', 'avg_rating', 'ratings_count',
#        'checkins_count'],
#       dtype='str')

# %%
print("y_test" in globals())
# Out:
# False
